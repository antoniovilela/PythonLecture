# %%
dados_comprimento = [
    150.0,
    150.1,
    150.8,
    150.0,
    150.0,
    144.1,
    150.0,
    150.3,
    149.9,
    150.0,
    150.0,
    150.1,
    150.2,
    150.0,
]
print (dados_comprimento)
# Out:
# [150.0, 150.1, 150.8, 150.0, 150.0, 144.1, 150.0, 150.3, 149.9, 150.0, 150.0, 150.1, 150.2, 150.0]

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(10,10))
plt.hist(dados_comprimento, bins=30)
plt.xlabel('L (cm)')
plt.ylabel('Nr. entradas')
# Out:
# Text(0, 0.5, 'Nr. entradas')
